# %%
# Common imports
import numpy as np
import os
import pandas as pd


# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# %%
df1 = pd.read_excel('säsongförslag.xlsx')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 3 columns):
# Bana         508 non-null object
# Datum        508 non-null datetime64[ns]
# Utdelning    508 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 12.0+ KB

# %%
df1.Utdelning.value_counts()
# Out:
# 4.0    105
# 2.0    102
# 5.0    101
# 3.0    100
# 1.0    100
# Name: Utdelning, dtype: int64

# %%
df2 = df1.set_index('Datum')

# %%
# Ta fram ett rullande medelvärde för att göra visualiseringen

# %%
med_utdelning?
# Out:
# Object `med_utdelning` not found.

# %%
fig, (ax) = plt.subplots(1, 1, figsize=(30,10), linewidth = 5, edgecolor = '.5')

ax.plot(df1.Datum, df1.Utdelning, linestyle = '--', linewidth = 3, color = '.2')

    
ax.set_title('Visualisering utdelninings historik', fontsize=30)

save_fig('tidsserie')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-4504b89b2db6> in <module>()
#       6 ax.set_title('Visualisering utdelninings historik', fontsize=30)
#       7
# ----> 8 save_fig('tidsserie')
#       9
#      10 plt.show()
#
# NameError: name 'save_fig' is not defined
